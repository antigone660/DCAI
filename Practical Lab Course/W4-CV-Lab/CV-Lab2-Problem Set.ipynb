# %% [markdown]
# Welcome to DSAA-6100-CV-Lab2! The aim of this problem set is to study different issues that appear when deploying models for real applications. These issues lead to a wide range of societal and ethical issues, some of which this problem set will try to briefly illustrate.
#
# ## Logistics
#
# To speed up the execution of the experiments we recommend using GPU acceleration. If you run this notebook on Google Colab, select GPU as your runtime type as follows:
#
# Runtime $\rightarrow$ Change runtime type $\rightarrow$ Hardware accelerator $\rightarrow$ GPU $\rightarrow$ Save.
#
#
# Training a single model with the default parameters for 40 epochs will take less than 15 minutes using a GPU in Google Colab (which should be available to you for free) or 3.5 hours using a CPU. You should at least train one model for Q1, but the rest of the problem set can be completed either with your model or a model provided by the instructors.
#
# If you get the message: "Notebook requires high RAM", press OK and ignore it.

# %% [markdown]
# # Initialization phase

# %%
import os
from tqdm import tqdm

data_dir = "./data"
zip_dir = "./data/zip" 

datasets_dir = data_dir + '/datasets'
models_dir = data_dir + '/models'
pretrained_models = data_dir + '/pretrained_models'

mias_dataset_dir = datasets_dir + '/mias_dataset'
external_dataset_dir = datasets_dir + '/external_dataset'

# %%
# !unzip -o {zip_dir}/mias_dataset.zip -d {mias_dataset_dir}
# !unzip -o {zip_dir}/external_dataset.zip -d {external_dataset_dir}
# Out:
# /bin/bash: /home/xieyupeng/anaconda3/lib/python3.11/site-packages/cv2/../../../../lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Archive:  ./data/zip/mias_dataset.zip
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_01035_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_01165_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_01035_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_01138_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_00554_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_00554_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_01138_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_01386_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_01307_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_01323_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_01889_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_01175_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_00160_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_01472_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_01889_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_01175_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_02198_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_00160_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_00160_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_01255_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_00160_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4588_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_01255_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4588_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_00617_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_00054_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_01175_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_01609_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_00555_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_00555_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4588_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_00608_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4568_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_00448_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_00448_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_00608_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4568_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4557_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4557_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4553_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4568_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4557_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4553_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4537_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4553_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4537_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4537_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4526_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4526_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01849_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4526_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4526_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4523_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01620_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01849_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_00710_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01431_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01620_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_00107_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01170_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_00710_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01436_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4609_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01170_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4606_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4605_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01095_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4606_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01095_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01073_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01073_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_00022_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4607_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4607_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4607_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4608_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4609_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4608_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4602_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_00022_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4608_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4602_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4602_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4603_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4603_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4604_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01076_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4603_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01009_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4604_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4605_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01009_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01076_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00999_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01000_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00849_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00950_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00802_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01000_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00802_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00849_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00719_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00719_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00695_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00586_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00661_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00661_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4588_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00586_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4582_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00568_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4582_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_01070_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00568_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00545_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00361_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4582_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_00728_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4574_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_00728_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4574_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_02198_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_01307_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4553_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4523_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4573_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_01250_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_00086_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4523_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_01250_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4573_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4511_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4511_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4573_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4574_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_01126_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4573_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4574_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_00212_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4511_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_01768_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3680_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_00212_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3680_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_01564_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3680_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4564_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4557_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_01768_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4564_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_01564_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3676_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4548_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4548_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3676_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4542_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3676_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4548_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4542_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00174_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_01501_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4552_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4541_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3663_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4542_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4542_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4552_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3663_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4552_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00174_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3663_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3648_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00001_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3616_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/malignant/P_01323_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4541_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00001_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3663_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3616_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_00086_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4568_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4539_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3666_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4603_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_02380_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3648_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4523_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3666_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4539_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_02380_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2020_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3622_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4539_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_02393_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3666_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3666_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00695_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4537_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_02393_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4541_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3645_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_01126_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4530_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3645_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2015_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4604_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4530_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3622_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/D_4511_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3655_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2015_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01846_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_02133_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2015_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4564_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01846_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3622_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3655_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4530_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4609_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2006_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_01501_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4608_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4501_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3622_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4501_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2006_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2006_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2006_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01545_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0619_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0619_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0607_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4552_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01548_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0607_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0607_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0607_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0588_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0588_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0568_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0568_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0568_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0568_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_00710_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3655_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0467_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4501_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3680_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4541_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_1972_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0467_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3624_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3676_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4501_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01548_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3637_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3648_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01545_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0703_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0703_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0618_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0618_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0703_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0602_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0703_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0602_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0605_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0602_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2015_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0602_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0605_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0605_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0566_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0566_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0566_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0508_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3607_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0619_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3642_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3642_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0508_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3624_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0508_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01582_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0467_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_1972_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0463_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0444_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0463_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0463_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0444_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0448_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0448_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0444_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0448_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0437_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0448_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0437_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0605_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0422_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0422_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4530_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0422_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0618_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0390_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0414_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0414_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3655_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0414_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0619_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0588_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_2035_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3637_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0422_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_1972_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_2035_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0471_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_01436_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01683_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0484_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_02133_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0473_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0484_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4609_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0473_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0508_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0478_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0473_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0478_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0478_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0451_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0451_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0437_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0478_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0452_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0452_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0442_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0442_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0443_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0450_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0452_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_1972_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0484_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3642_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0443_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0450_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/malignant/P_01070_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_1967_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01524_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0414_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0471_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_1967_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3642_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_2035_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3637_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_2034_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3624_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0471_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3616_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01524_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_2034_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0463_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3637_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_1969_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0484_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_1969_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3626_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_2035_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01359_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01384_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0588_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_2034_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3626_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_2016_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_1969_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_2034_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3643_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0390_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0452_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0467_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01359_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3626_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_2016_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_2016_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3626_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_1967_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4548_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_1978_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0708_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_1978_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3645_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3643_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_1978_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2036_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0708_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3643_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2036_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01582_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3643_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2036_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_1973_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_1973_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_1973_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_1969_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_1973_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3616_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_1968_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3620_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2036_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3645_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_1968_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2023_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2023_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_1968_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2023_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3620_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_2016_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3620_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2020_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3607_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3607_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2020_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2020_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3607_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0618_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00738_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00738_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00409_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00612_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0437_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00171_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00409_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0708_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01755_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01720_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01702_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01715_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01715_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0473_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01702_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01619_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01720_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01485_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01274_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0451_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01619_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01327_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01406_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01280_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0450_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_2023_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0443_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01280_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0451_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0442_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4564_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0333_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0333_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0333_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/benign/P_00710_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0333_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_1967_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00099_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0341_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0311_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0341_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0311_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0341_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/benign/P_01609_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0326_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0326_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0326_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0311_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0326_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4607_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0296_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0296_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4604_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0296_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01485_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4606_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4597_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4606_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0444_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4605_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01181_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01238_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01142_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01182_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01238_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01182_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01142_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01150_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01150_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01181_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01342_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00841_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00731_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00723_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0442_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4596_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00841_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4596_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00666_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4597_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00694_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0443_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01286_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4598_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00666_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4599_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01286_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01072_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/B_3620_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00634_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00634_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4597_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4598_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00992_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4601_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01091_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0311_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4602_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4601_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4600_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4601_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00992_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_01755_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4590_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4591_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4591_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0341_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4593_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0471_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00442_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00989_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4599_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4593_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4599_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4595_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00426_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0296_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00731_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0273_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0273_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00989_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4598_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0277_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4592_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00784_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0566_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4592_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0277_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00784_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0277_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4599_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00772_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00772_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0273_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/benign/P_00171_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4600_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4597_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0264_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4593_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4593_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4592_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0708_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0264_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0264_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00925_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4594_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00925_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4601_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0277_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/D_4582_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0258_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00954_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0258_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4600_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_0273_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/B_3624_1.RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4592_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00954_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00473_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00438_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00121_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00189_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/normal/D_4594_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00189_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00316_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00316_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_02501_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/test/normal/A_1978_1.RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_02501_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01635_RIGHT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00164_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01140_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00438_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00987_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01217_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01140_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0390_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01072_LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0390_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_00485_LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0351_1.LEFT_MLO.jpg
#   inflating: ./data/datasets/mias_dataset/train/malignant/P_01635_RIGHT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0351_1.LEFT_CC.jpg
#   inflating: ./data/datasets/mias_dataset/val/normal/A_0351_1.RIGHT_CC.jpg
# ...
#   inflating: ./data/datasets/external_dataset/test/normal/000123.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000233.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000124.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000189.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000000.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000111.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000098.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000035.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000032.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000116.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000201.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000164.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000273.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000118.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000091.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000040.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000208.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000047.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000163.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000056.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000087.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000219.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000265.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000172.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000262.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000175.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000051.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000080.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000109.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000023.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000210.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000058.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000089.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000217.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000100.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000024.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000135.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000222.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000011.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000149.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000198.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000301.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000016.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000288.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000259.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000132.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000225.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000018.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000140.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000286.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000257.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000191.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000063.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000147.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000281.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000250.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000196.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000261.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000176.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000052.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000055.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000084.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000029.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000266.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000171.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000214.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000103.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000027.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000020.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000178.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000213.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000104.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000302.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000015.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000069.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000226.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000136.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000221.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000305.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000012.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000060.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000138.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000282.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000144.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000195.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000253.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000285.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000143.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000192.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000254.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000067.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000228.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000183.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000245.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000294.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000152.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000239.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000076.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000129.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000071.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000184.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000293.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000155.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000230.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000127.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000003.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000004.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000237.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000120.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000078.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000169.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000031.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000115.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000202.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000112.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000205.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000279.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000036.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000095.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000044.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000160.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000277.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000038.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000167.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000270.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000092.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000142.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000193.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000255.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000066.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000229.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000061.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000283.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000145.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000252.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000220.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000304.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000013.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000303.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000014.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000130.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000227.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000021.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000179.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000212.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000105.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000102.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000054.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000028.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000267.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000170.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000177.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000053.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000166.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000093.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000042.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000045.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000161.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000276.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000039.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000113.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000204.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000278.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000037.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000168.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000030.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000114.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000203.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000236.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000121.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000079.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000231.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000126.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000002.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000128.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000070.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000185.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000243.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000292.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000154.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000182.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000244.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000295.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000153.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000238.jpg
#   inflating: ./data/datasets/external_dataset/test/normal/000077.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000074.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000199.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000017.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000101.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000218.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000158.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000206.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000096.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000107.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000268.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000242.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000043.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000194.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000284.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000068.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000137.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000026.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000215.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000260.jpg
#   inflating: ./data/datasets/external_dataset/test/benign/000094.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000122.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000097.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000046.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000272.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000211.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000256.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000274.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000049.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000290.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000064.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000131.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000083.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000085.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000082.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000269.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000139.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000005.jpg
#   inflating: ./data/datasets/external_dataset/test/malignant/000271.jpg

# %% [markdown]
# # **Problem 1** Train an Image Classifier
#
# Experiment with some of the following hyperparameters, techniques, and model types by modifying the cells that follow:
#
# *   Starting with a pretrained model
# *   Data augmentation
# *   Weight initialization
# *   Residual connections (ResNet) and dense connections (DenseNet), compared to networks without them (VGGNet, AlexNet)
# *   Number of layers, or number of layer features
# *   Type of optimizer
# *   Learning rate and/or schedule
# *   Early stopping
#
#
#
# For the rest of the problem set, you can either use your model (save the best performing one) or the one trained by the instructors (inside the pretrained_models folder). If the test performance of your own model is less than 93%, please use the latter.

# %% [markdown]
# ## Section 1: Training a Model
#
# This code was adapted from <https://pytorch.org/tutorials/beginner/finetuning_torchvision_models_tutorial.html>
#
# You are free to delete this code entirely and start from scratch, or modify it in whatever way you choose to implement your proposed modifications.

# %% [markdown]
# ### Dependencies

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
# You might not have tqdm, which gives you nice progress bars
# !pip install tqdm
from tqdm.notebook import tqdm
import os
import copy
import pandas as pd
import PIL 
import random
from collections import defaultdict

# For reproducibility
torch.manual_seed(6100)
  
# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print("Using the GPU!")
else:
    print("WARNING: Could not find GPU! Using CPU only")
    print("You may want to try to use the GPU in Google Colab by clicking in:")
    print("Runtime > Change Runtime type > Hardware accelerator > GPU.")
# Out:
# /bin/bash: /home/xieyupeng/anaconda3/lib/python3.11/site-packages/cv2/../../../../lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: tqdm in /home/xieyupeng/anaconda3/lib/python3.11/site-packages (4.65.0)
# Using the GPU!

# %% [markdown]
# ### Initialize an Empty Model
#
# First, we need to initialize an empty model, that will input an image, and output a classification. Each model is a little different, so we'll make a helper function that takes in an architecture name, and outputs a model. This is only meant as a guideline, and you can try using different models! `torchvision.models` has other common architectures, and variations on these (like ResNet-50 and ResNet-101), so you may want to try those out.
#
# We also add a `resume_from` argument to specify model weights to load, In case you save a model and want to use it again.

# %%
def initialize_model(model_name, num_classes, resume_from = None, use_pretrained = False):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    # The model (nn.Module) to return
    model_ft = None
    # The input image is expected to be (input_size, input_size)
    input_size = 0
    
    # By default, all parameters will be trained (useful when you're starting from scratch)
    # Within this function you can set .requires_grad = False for various parameters, if you
    # don't want to learn them

    if model_name == "resnet":
        """ Resnet18
        """
        model_ft = models.resnet18(pretrained=use_pretrained)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 224
        
    elif model_name == "resnet50":
        """ Resnet50
        """
        model_ft = models.resnet50(pretrained=use_pretrained)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "alexnet":
        """ Alexnet
        """
        model_ft = models.alexnet(pretrained=use_pretrained)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "vgg":
        """ VGG11_bn
        """
        model_ft = models.vgg11_bn(pretrained=use_pretrained)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "squeezenet":
        """ Squeezenet
        """
        model_ft = models.squeezenet1_0(pretrained=use_pretrained)
        model_ft.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        model_ft.num_classes = num_classes
        input_size = 224

    elif model_name == "densenet":
        """ Densenet
        """
        model_ft = models.densenet121(pretrained=use_pretrained)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_classes) 
        input_size = 224

    else:
        raise Exception("Invalid model name!")
    
    if resume_from is not None:
        print("Loading weights from %s" % resume_from)
        model_ft.load_state_dict(torch.load(resume_from))
    
    return model_ft, input_size

# %% [markdown]
# ### Data Loading
#
# With the input size from the model, we can now load the dataset

# %%
from torchvision.transforms.functional import to_grayscale

def get_image_transforms():
    # How to transform the image when you are loading them.
    # you'll likely want to mess with the transforms on the training set.
    
    # We convert the image to a [C,H,W] tensor, then normalize it to values with a given mean/stdev. These normalization constants
    # are derived from the mean/stdev of the ImageNet training set which was used to pretrain our models.

    transform = transforms.Compose([
            transforms.Grayscale(num_output_channels=3),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ])
    return transform

def get_dataloaders(dataset_dir, input_size, batch_size, shuffle = True, transform=get_image_transforms()):
    data_transforms = {
        'train': transform,
        'val': transform,
        'test': transform
    }
    # Create training, validation and test datasets
    image_datasets = {x: datasets.ImageFolder(os.path.join(dataset_dir, x), data_transforms[x]) for x in data_transforms.keys()}
    # Create training, validation and test dataloaders
    # Never shuffle the test set
    dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=False if x != 'train' else shuffle, num_workers=4) for x in data_transforms.keys()}
    return dataloaders_dict

# %% [markdown]
# ### Training
# Next, let's make a helper function that trains the given model

# %%
def train_model(model, dataloaders, criterion, optimizer, save_dir = None, save_all_epochs=False, num_epochs=25):
    '''
    model: The NN to train
    dataloaders: A dictionary containing at least the keys 
                 'train','val' that maps to Pytorch data loaders for the dataset
    criterion: The Loss function
    optimizer: The algorithm to update weights 
               (Variations on gradient descent)
    num_epochs: How many epochs to train for
    save_dir: Where to save the best model weights that are found, 
              as they are found. Will save to save_dir/weights_best.pt
              Using None will not write anything to disk
    save_all_epochs: Whether to save weights for ALL epochs, not just the best
                     validation error epoch. Will save to save_dir/weights_e{#}.pt
    '''
    since = time.time()

    val_acc_history = []
    train_acc_history = []
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            # TQDM has nice progress bars
            for inputs, labels in tqdm(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)

                    # torch.max outputs the maximum value, and its index
                    # Since the input is batched, we take the max along axis 1
                    # (the meaningful outputs)
                    _, preds = torch.max(outputs, 1)

                    # backprop + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)
            

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'train':
                train_acc_history.append(epoch_acc)
            if phase == 'val':
                val_acc_history.append(epoch_acc)
            if save_all_epochs:
                torch.save(model.state_dict(), os.path.join(save_dir, f'weights_{epoch}.pt'))

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # save and load best model weights
    torch.save(best_model_wts, os.path.join(save_dir, 'weights_best_val_acc.pt'))
    torch.save(model.state_dict(), os.path.join(save_dir, 'weights_last.pt'.format(epoch)))
    model.load_state_dict(best_model_wts)
    return model, val_acc_history, train_acc_history

# %% [markdown]
# ### Optimizer & Loss
# We need a loss function, and an optimization function to use to try to reduce that loss.

# %%
def make_optimizer(model, learning_rate, print_parameters=False):
    # Get all the parameters
    params_to_update = model.parameters()
    if print_parameters:
      print("Params to learn:")
      for name, param in model.named_parameters():
          if param.requires_grad == True:
              print("\t",name)

 
    optimizer = optim.SGD(params_to_update, lr=learning_rate, momentum=0.9)
    return optimizer

def get_loss():
    # Create an instance of the loss function
    criterion = nn.CrossEntropyLoss()
    return criterion

# %% [markdown]
# ### Parameters
#
# Here, we set up some of the various parameters that we can change to run the code. You can add change the values given here, or add new ones! This is just a template.
#
# Our data is conveniently set up to follow the expected format of the  `ImageFolder <https://pytorch.org/docs/stable/torchvision/datasets.html#torchvision.datasets.ImageFolder>`__
# dataset class, rather than writing our own custom dataset.
#
# The ``model_name`` input is the name of the model you wish to use. We've provided starter code that initializes these models using provided models in TorchVision (a PyTorch library)
#
# The code as is supports the following values: [resnet, alexnet, vgg, squeezenet, densenet]
#
# The other inputs are as follows: ``num_classes`` is the number of
# classes in the dataset, 3 here, ``batch_size`` is the batch size used for
# training and may be adjusted according to the capability of your
# machine, ``num_epochs`` is the number of training epochs (passes through the dataset) we want to run.

# %%
# Models to choose from [resnet, alexnet, vgg, squeezenet, densenet]
# You can add your own, or modify these however you wish!
model_name =  ###Your own###

# Number of classes in the dataset, normal, benign, malignant
num_classes = 3

# Batch size for training (change depending on how much memory you have)
batch_size = 32

# Shuffle the input data?
shuffle_datasets = True

# Number of epochs to train for 
num_epochs = ###Your own###

# Learning rate
learning_rate =  ###Your own###

### IO
# Path to a model file to use to start weights at
resume_from = None

# Whether to use a pretrained model, trained for classification in Imagenet-1k 
pretrained = False

# Save all epochs so that you can select the model from a particular epoch
save_all_epochs = False

# Whether to use early stopping (load the model with best accuracy), or not
early_stopping = True

# Directory to save weights to
save_dir = models_dir + '/trained_model_1'
os.makedirs(save_dir, exist_ok=True)

# %% [markdown]
# ### Tying it all together - Training

# %%
# Initialize the model for this run
# train model_1
model_1, input_size = initialize_model(model_name = model_name, num_classes = num_classes, resume_from=resume_from, use_pretrained=pretrained)
dataloaders = get_dataloaders(mias_dataset_dir, input_size, batch_size, shuffle_datasets)
criterion = get_loss()

# Move the model to the gpu if needed
model_1 = model_1.to(device)

optimizer_1 = make_optimizer(model_1, learning_rate)

# Train the model!
trained_model_1, validation_history_1, train_history_1 = train_model(model=model_1, 
                                                                     dataloaders=dataloaders, 
                                                                     criterion=criterion, 
                                                                     optimizer=optimizer_1,
                                                                     save_dir=save_dir, 
                                                                     save_all_epochs=save_all_epochs, 
                                                                     num_epochs=num_epochs)
del model_1, optimizer_1, trained_model_1
# Out:
# Epoch 1/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.4995 Acc: 0.8701
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.4208 Acc: 0.8812
#
# Epoch 2/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.4361 Acc: 0.8709
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.4024 Acc: 0.8812
#
# Epoch 3/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.4183 Acc: 0.8709
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.3842 Acc: 0.8812
#
# Epoch 4/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.3989 Acc: 0.8738
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.5478 Acc: 0.8812
#
# Epoch 5/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.3758 Acc: 0.8754
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.4541 Acc: 0.8482
#
# Epoch 6/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.3508 Acc: 0.8782
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.5132 Acc: 0.8416
#
# Epoch 7/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.3801 Acc: 0.8762
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.8284 Acc: 0.5743
#
# Epoch 8/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.3461 Acc: 0.8839
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 1.8391 Acc: 0.8812
#
# Epoch 9/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.3861 Acc: 0.8787
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.4249 Acc: 0.8911
#
# Epoch 10/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.3540 Acc: 0.8831
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.7790 Acc: 0.8812
#
# Training complete in 0m 26s
# Best val Acc: 0.891089

# %% [markdown]
# ### Load trained models

# %%
# Load your final model, that we will use for the rest of the PSET.
if early_stopping:
  weights_file = save_dir + '/weights_best_val_acc.pt'
else:
  weights_file = save_dir + '/weights_last.pt'
model_yours, _ = initialize_model(model_name = model_name, num_classes = num_classes, resume_from=resume_from, use_pretrained=pretrained)

# Move the model to the gpu if needed
model_yours = model_yours.to(device)

# Load weights for model_yours
model_yours.load_state_dict(torch.load(weights_file))

# Load instructors model:
model_inst = torch.load(pretrained_models + '/instructors_model.pth')
model_inst = model_inst.to(device)

# set models to eval mode
model_yours = model_yours.eval()
model_inst = model_inst.eval()

# %% [markdown]
# ## Section 2: Inference using a model
#
# Now that we've trained a model, we would like to use it for inference on the test data. We will use a function that can compute top-k performance (i.e., whether the correct prediction is in the top-k predicted classes) but for this problem set, we will set k = 1, as there are only 3 classes.

# %%
def evaluate(model, dataloader, criterion, is_labelled = False, generate_labels = True, k = 5):
    # If is_labelled, we want to compute loss, top-1 accuracy and top-5 accuracy
    # If generate_labels, we want to output the actual labels
    # Set the model to evaluate mode
    model.eval()
    running_loss = 0
    running_top1_correct = 0
    running_top5_correct = 0
    predicted_labels = []
    gt_labels = []

    # Iterate over data.
    # TQDM has nice progress bars
    for inputs, labels in tqdm(dataloader):
        inputs = inputs.to(device)
        labels = labels.to(device)
        tiled_labels = torch.stack([labels.data for i in range(k)], dim=1) 
        # Makes this to calculate "top 5 prediction is correct"
        # [[label1 label1 label1 label1 label1], [label2 label2 label2 label label2]]

        # forward
        # track history if only in train
        with torch.set_grad_enabled(False):
            # Get model outputs and calculate loss
            outputs = model(inputs)
            if is_labelled:
                loss = criterion(outputs, labels)

            # torch.topk outputs the maximum values, and their indices
            # Since the input is batched, we take the max along axis 1
            # (the meaningful outputs)
            _, preds = torch.topk(outputs, k=k, dim=1)
            if generate_labels:
                # We want to store these results
                nparr = preds.cpu().detach().numpy()
                predicted_labels.extend([list(nparr[i]) for i in range(len(nparr))])
                gt_labels.extend(np.array(labels.cpu()))

        if is_labelled:
            # statistics
            running_loss += loss.item() * inputs.size(0)
            # Check only the first prediction
            running_top1_correct += torch.sum(preds[:, 0] == labels.data)
            # Check all 5 predictions
            running_top5_correct += torch.sum(preds == tiled_labels)
        else:
            pass

    # Only compute loss & accuracy if we have the labels
    if is_labelled:
        epoch_loss = float(running_loss / len(dataloader.dataset))
        epoch_top1_acc = float(running_top1_correct.double() / len(dataloader.dataset))
        epoch_top5_acc = float(running_top5_correct.double() / len(dataloader.dataset))
    else:
        epoch_loss = None
        epoch_top1_acc = None
        epoch_top5_acc = None
    
    # Return everything
    return epoch_loss, epoch_top1_acc, gt_labels, predicted_labels

# %%
# Get data on the validation set
# Setting this to false will be a little bit faster
generate_validation_labels = True
val_loss_yours, val_top1_yours, _, val_labels_yours = evaluate(model_yours, dataloaders['val'], criterion, is_labelled = True, generate_labels = generate_validation_labels, k = 1)
# Get predictions for the test set
test_loss_yours, test_top1_yours, _, test_labels_yours = evaluate(model_yours, dataloaders['test'], criterion, is_labelled = True, generate_labels = generate_validation_labels, k = 1)

val_loss_inst, val_top1_inst, _, val_labels_inst = evaluate(model_inst, dataloaders['val'], criterion, is_labelled = True, generate_labels = generate_validation_labels, k = 1)
# Get predictions for the test set
test_loss_inst, test_top1_inst, _, test_labels_inst = evaluate(model_inst, dataloaders['test'], criterion, is_labelled = True, generate_labels = generate_validation_labels, k = 1)

print("Your Trained model: ")
print("Val Top-1 Accuracy: {}".format(val_top1_yours))
print("Test Top-1 Accuracy: {}".format(test_top1_yours))

print("Instructors model: ")
print("Val Top-1 Accuracy: {}".format(val_top1_inst))
print("Test Top-1 Accuracy: {}".format(test_top1_inst))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Your Trained model:
# Val Top-1 Accuracy: 0.8910891089108911
# Test Top-1 Accuracy: 0.8790849673202614
# Instructors model:
# Val Top-1 Accuracy: 0.9636963696369637
# Test Top-1 Accuracy: 0.9477124183006537

# %% [markdown]
# Select either your model or the instructor model for the next questions. If your model does not achieve high accuracy (at least 93% on the test set), you should use the instructors model (model_inst).

# %%
model = model_inst
# model = model_yours

# %% [markdown]
# # **Problem 2** Metrics: Accuracy isn't everything
#
# Let's define a function to get detailed evaluation results on the test set.

# %%
# Wrapper to easily evaulate a model given a model and the set of dataloaders
def get_eval_results(model, dataloaders):
    model.eval()
    true_label_list = []
    outputs_list = []
    predicted_label_list = []
    original_image_list = []

    # TQDM has nice progress bars
    for inputs, labels in tqdm(dataloaders['test']):
        inputs = inputs.to(device)
        labels = labels.to(device)
        with torch.set_grad_enabled(False):
            # Get model outputs and calculate loss
            outputs = model(inputs)
            true_label_list.append(labels)
            original_image_list.append(inputs)
            outputs_list.append(outputs)
            _, preds = torch.topk(outputs, k=1, dim=1)
            predicted_label_list.append(preds)
    return torch.concat(true_label_list).unsqueeze(-1).cpu().numpy(), \
           torch.concat(predicted_label_list).cpu().numpy(), \
           torch.softmax(torch.concat(outputs_list), dim=1).cpu().numpy(), \
           torch.concat(original_image_list).cpu().numpy()

## Please make sure you understand what outputs means here
y_label, y_pred, outputs, inputs =  get_eval_results(model, dataloaders)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ## Confusion Matrix
#
# The first simple method that we will use to delve deeper into the results is the confusion matrix. Complete the function below and plot your confusion matrix.

# %%
### Complete your code here to plot your confusion matrix.
### Please avoid using sklearn.metrics.confusion_matrix in your function: build your confusion matrix from scratch! You may, however, want to plot its output to make sure you're doing the right thing!
### Feel free to import necessary packages.
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def plot_confusion_matrix(y_label, y_pred, title='Confusion matrix'):
    ### TODO 1
    """
    Plot a confusion matrix using ground truth and predictions.
    
    :param y_label: Ground truth labels.
    :param y_pred: Predicted labels.
    :param title: Title for the confusion matrix plot.
    """

    
print(dataloaders['test'].dataset.class_to_idx)
plot_confusion_matrix(y_label, y_pred)
# Out:
# {'benign': 0, 'malignant': 1, 'normal': 2}

# %% [markdown]
# ## Precision-Recall Curve
#
# Assume that the malignant class is our positive class, and the rest are negative classes. In this scenario, a positive prediction happens when our model's prediction for class malignant is *above a user-defined threshold*. That means that a True Positive (TP) happens when we have a positive prediction and the ground truth label is malignant. A False Positive (FP) happens when we have a positive prediction and the ground truth label is something other than malignant. True negatives (TN) and false negatives (FN) follow the same logic.
#
# Remember that Precision = TP/(TP+FP) and Recall = TP/(TP+FN).
#
# **Calculate precision and recall for 1000 evenly spaced thresholds between 0 and 1, and plot the precision-recall curve of your selected model. Then, compute the AUC leveraging the function trapz from numpy, and display the AUC on the plot.** Your output for this question should be one plot, with precision on the Y axis and recall on the X axis.

# %%
### write your code here to plot your precision-recall curve for the model 
### please plot it without using metrics packages here for better understanding 

### use the returned values from the get_eval_results() above 
### TODO 2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # **Problem 3** What is the model looking at?
#
#
# In the following code snippet, we use the following pytorch package that implements different variations of CAM:
# https://github.com/jacobgil/pytorch-grad-cam

# %%
# !pip install grad-cam

import random
from collections import defaultdict

from pytorch_grad_cam import GradCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM, FullGrad
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image

# %%
def plot_cams(target_dataloaders, cam_method=GradCAM, class_id='gt'):
  assert class_id in ['gt', 'pred'] or type(class_id) is int and class_id < 3
  for split in ['train', 'val', 'test']:
    target_layers = [model.layer4[-1]]
    fig, axs = plt.subplots(2, 6, figsize=(14, 7))
    fig.suptitle("Examples split {}, class {}".format(split, class_id), fontsize=16)

    split_dataset = target_dataloaders[split].dataset
    indices_per_class = defaultdict(list)
    for i, (_, c) in enumerate(split_dataset.imgs):
      indices_per_class[c].append(i)

    random.seed(1337)  
    indices = []
    for c in range(3):
      indices.extend(random.sample(indices_per_class[c], 4))

    for dataset_i, ax in zip(indices, axs.flatten()):
      input_tensor, class_idx = split_dataset[dataset_i]
      input_tensor = input_tensor[None,...].cuda()

      # Construct the CAM object once, and then re-use it on many images:
      cam = cam_method(model=model, target_layers=target_layers, use_cuda=not device == 'cpu')
      pred_class_idx = model(input_tensor).argmax()

      # We have to specify the target we want to generate
      # the Class Activation Maps for
      if class_id is int:
        target_class_id = class_id
      else:
        target_class_id = pred_class_idx if class_id == 'pred' else class_idx        
      targets = [ClassifierOutputTarget(target_class_id)]

      # You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
      grayscale_cam = cam(input_tensor=input_tensor, targets=targets)

      # In this example grayscale_cam has only one image in the batch:
      grayscale_cam = grayscale_cam[0, :]
      rgb_image = np.array(input_tensor[0].cpu())
      rgb_image = (rgb_image - rgb_image.min())/ (rgb_image.max() - rgb_image.min())
      visualization = show_cam_on_image(rgb_image.transpose((1,2,0)), grayscale_cam, use_rgb=True)
      
      ax.set_title('True : %s\n Predicted: %s' %(split_dataset.classes[class_idx], split_dataset.classes[pred_class_idx]))
      ax.imshow(visualization)

# %%
# Substitute GradCAM for one of the following, to test other methods:
# GradCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM, FullGrad
# Also substitute class_id for pred, or a class id in [0,1,2] to check different output.
plot_cams(dataloaders, cam_method=GradCAM, class_id='gt')

# %% [markdown]
# # **Problem 4** Evaluation on am External Dataset

# %% [markdown]
# ## Compare performances

# %%
dataloaders_external = get_dataloaders(external_dataset_dir, input_size, batch_size, shuffle_datasets)

test_loss, test_top1, gt_labels, pred_labels = evaluate(model, dataloaders['test'], criterion, is_labelled = True, generate_labels = True, k = 1)
test_loss_ext, test_top1_ext, gt_labels_ext, pred_labels_ext = evaluate(model, dataloaders_external['test'], criterion, is_labelled = True, generate_labels = True, k = 1)

print("Top-1 Acc: {}".format(test_top1))
print("External Top-1 Acc: {}".format(test_top1_ext))

plot_confusion_matrix(gt_labels_ext, pred_labels_ext, title='CM External dataset')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Top-1 Acc: 0.9477124183006537
# External Top-1 Acc: 0.8790849673202614

# %% [markdown]
# ## Compare examples

# %%
import random
from collections import defaultdict

def plot_samples(dataloaders_external, title=''):
  fig, axs = plt.subplots(2, 6, figsize=(14, 7))
  fig.suptitle(title, fontsize=16)

  dataset = dataloaders_external['test'].dataset
  indices_per_class = defaultdict(list)
  for i, (_, c) in enumerate(dataset.imgs):
    indices_per_class[c].append(i)

  random.seed(1337)  
  indices = []
  for c in range(3):
    indices.extend(random.sample(indices_per_class[c], 4))

  # remove normalize transforms for plotting
    inv_normalize = transforms.Normalize(
        mean=[-0.485/0.229, -0.456/0.224, -0.406/0.255],
        std=[1/0.229, 1/0.224, 1/0.255]
    )

  for dataset_i, ax in zip(indices, axs.flatten()):
    img, class_idx = dataset[dataset_i]
    img = inv_normalize(img)
    ax.set_title('True : %s' %(dataset.classes[class_idx]))
    if len(img.shape) == 2:
      img = np.tile(img[:,:,None], (1,1,3))
    img = np.array((img*255).clip(0, 255), dtype='uint8')
    ax.imshow(img.transpose((1,2,0)))

# Plot some samples of each of the datasets:
plot_samples(dataloaders, 'Original dataset samples')
plot_samples(dataloaders_external, 'External dataset samples')

# %% [markdown]
# ## New transformations
# Use some of the available PyTorch transformations in:
#
# https://pytorch.org/vision/stable/transforms.html#transforms-on-pil-image-and-torch-tensor

# %%
from torchvision.transforms.functional import to_grayscale
from torchvision import transforms

# TODO:
external_transforms = transforms.Compose([

])

# END TODO
transform = transforms.Compose([external_transforms,
                                get_image_transforms()])

modified_original_dataloaders = get_dataloaders(mias_dataset_dir, input_size, batch_size, shuffle_datasets, transform)
plot_samples(modified_original_dataloaders, 'Original dataset samples')
plot_samples(dataloaders_external, 'External dataset samples')

# %% [markdown]
# # **Problem 5** Class Imbalance

# %%
from collections import defaultdict 
# First we will compute statistics of the dataset:
dataloaders = get_dataloaders(mias_dataset_dir, input_size, batch_size, shuffle_datasets)
train_dataset = dataloaders['train'].dataset

samples_per_class = [0 for _ in range(3)]
for _, class_idx in train_dataset:
  samples_per_class[class_idx] += 1

print("Samples per class:")
for c_idx in range(3):
  print("Class {} ({}): {} samples".format(c_idx, train_dataset.classes[c_idx], samples_per_class[c_idx]))
# Out:
# Samples per class:
# Class 0 (benign): 186 samples
# Class 1 (malignant): 132 samples
# Class 2 (normal): 2146 samples

# %% [markdown]
# ## Loss reweighting
#
# Complete the line of code specified to compute (and print out) the weights per class to balance the class losses.

# %%
total_samples = sum(samples_per_class)

# TODO: Compute the weights per class so that the loss is balanced. 
#       We are expecting one weight per class (weights_per_class.shape = [3])
#       If done correctly, the sum of weights over all samples should sum up to total_samples

# Compute the weights per class so that the loss is balanced. 
weights_per_class = ...
...

# ENDTODO

weights_per_class = weights_per_class.to(device)
reweighted_criterion = nn.CrossEntropyLoss(weight=weights_per_class)   

# DO NOT REMOVE THIS LINE:
print(weights_per_class)
# Out:
# tensor([1.2020, 1.6938, 0.1042], device='cuda:0')

# %% [markdown]
# ## Dataset rebalancing
# Complete the following lines to modify the data loader so that samples for the three classes are balanced. For simplicity, you are allowed to select an element at random, and ignore the *item* argument of the dataset.__getitem__ function.
#
# Then, excecute the training loop with the modified dataset/dataloader and print the number of samples per class in the rebalanced dataset with the code provided

# %%
import random
from collections import defaultdict

class RebalancedDataset(datasets.ImageFolder):
  def __init__(self, class_probabilities, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.class_probabilities = class_probabilities
    self.items_per_class = defaultdict(list)
    
    for item_i, (_, c) in enumerate(self.imgs):
      self.items_per_class[c].append(item_i)

  def __getitem__(self, i_ignored):
    # ignores argument, and returns an element at random with reweighted class
    if i_ignored >= len(self):
      raise IndexError('Index is too large') # Exception required so that the iterator ends after len(self) samples

    # TODO: select a class at random following self.class_probabilities, and then select a random element for the class
    class_i = ...
    i = ...
    # ENDTODO
    return super().__getitem__(i)

# %%
# Replicates the original get_dataloaders, but in this case we substitute the training dataset for the RebalancedDataset
def get_dataloaders_rebalanced(class_probabilities, dataset_dir, input_size, batch_size, shuffle = True):
    data_transforms = {
        'train': get_image_transforms(),
        'val': get_image_transforms(),
        'test': get_image_transforms()
    }

    # Create training and validation datasets
    image_datasets = {'train': RebalancedDataset(class_probabilities, os.path.join(dataset_dir, 'train'), data_transforms['train']),
                      'val': datasets.ImageFolder(os.path.join(dataset_dir, 'val'), data_transforms['val']),
                      'test': datasets.ImageFolder(os.path.join(dataset_dir, 'test'), data_transforms['test'])}
    # Create training and validation dataloaders
    # Never shuffle the test set
    dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=False if x != 'train' else shuffle, num_workers=4) for x in data_transforms.keys()}
    return dataloaders_dict

# %%
class_probabilities = [1/3 for _ in range(3)]
dataloaders_rebalanced = get_dataloaders_rebalanced(class_probabilities, mias_dataset_dir, input_size, batch_size, shuffle_datasets)

train_dataset_rebalanced = dataloaders_rebalanced['train'].dataset

# %%
from collections import defaultdict 

samples_per_class_rebalanced = [0 for _ in range(3)]
for _, class_idx in tqdm(train_dataset_rebalanced):
  samples_per_class_rebalanced[class_idx] += 1

print("Rebalanced samples per class:")
for c_idx in range(3):
  print("Class {} ({}): {} samples".format(c_idx, train_dataset_rebalanced.classes[c_idx], samples_per_class_rebalanced[c_idx]))
# Out:
#   0%|          | 0/2464 [00:00<?, ?it/s]
# Rebalanced samples per class:
# Class 0 (benign): 840 samples
# Class 1 (malignant): 844 samples
# Class 2 (normal): 780 samples

# %% [markdown]
# ## Results of approaches for addressing class imbalance
#
# Train the models with the modified criterion and rebalanced dataloader by running the next two cells.

# %%
model_reweighted, input_size = initialize_model(model_name = model_name, num_classes = num_classes, resume_from=resume_from, use_pretrained=pretrained)

model_reweighted = model_reweighted.to(device)
optimizer_reweighted = make_optimizer(model_reweighted, learning_rate)
trained_reweighted, validation_history_reweighted, train_history_reweighted = train_model(model=model_reweighted, 
                                                                                          dataloaders=dataloaders, 
                                                                                          criterion=reweighted_criterion, 
                                                                                          optimizer=optimizer_reweighted,
                                                                                          save_dir=save_dir, 
                                                                                          save_all_epochs=save_all_epochs, 
                                                                                          num_epochs=num_epochs)
# Out:
# Epoch 1/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 1.1149 Acc: 0.4655
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.8724 Acc: 0.7393
#
# Epoch 2/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 1.0289 Acc: 0.5365
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 1.6371 Acc: 0.1155
#
# Epoch 3/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 1.0165 Acc: 0.5962
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 1.0450 Acc: 0.4554
#
# Epoch 4/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.9297 Acc: 0.6339
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.6294 Acc: 0.8812
#
# Epoch 5/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.8724 Acc: 0.6753
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 3.0159 Acc: 0.8812
#
# Epoch 6/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.8121 Acc: 0.6920
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 1.3157 Acc: 0.3069
#
# Epoch 7/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.7611 Acc: 0.7179
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 2.3923 Acc: 0.8812
#
# Epoch 8/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.7240 Acc: 0.7451
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 2.2862 Acc: 0.8812
#
# Epoch 9/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.6388 Acc: 0.7898
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 5.5168 Acc: 0.8812
#
# Epoch 10/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.6315 Acc: 0.7772
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 3.9882 Acc: 0.8812
#
# Training complete in 0m 27s
# Best val Acc: 0.881188

# %%
model_rebalanced, input_size = initialize_model(model_name = model_name, num_classes = num_classes, resume_from=resume_from, use_pretrained=pretrained)

model_rebalanced = model_rebalanced.to(device)
optimizer_rebalanced = make_optimizer(model_rebalanced, learning_rate)
trained_rebalanced, validation_history_rebalanced, train_history_rebalanced = train_model(model=model_rebalanced, 
                                                                                          dataloaders=dataloaders_rebalanced, 
                                                                                          criterion=criterion, 
                                                                                          optimizer=optimizer_rebalanced,
                                                                                          save_dir=save_dir, 
                                                                                          save_all_epochs=save_all_epochs, 
                                                                                          num_epochs=num_epochs)
# Out:
# Epoch 1/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 1.0638 Acc: 0.4152
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.7842 Acc: 0.7195
#
# Epoch 2/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.8935 Acc: 0.5889
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.8372 Acc: 0.6436
#
# Epoch 3/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.8111 Acc: 0.6489
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.5853 Acc: 0.8218
#
# Epoch 4/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.7440 Acc: 0.6822
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 1.3244 Acc: 0.8812
#
# Epoch 5/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.7394 Acc: 0.6806
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.7601 Acc: 0.8812
#
# Epoch 6/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.5745 Acc: 0.7914
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.9393 Acc: 0.6139
#
# Epoch 7/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.4584 Acc: 0.8340
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.6326 Acc: 0.7690
#
# Epoch 8/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.2961 Acc: 0.9136
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 4.5714 Acc: 0.8812
#
# Epoch 9/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.0936 Acc: 0.9834
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.2020 Acc: 0.9274
#
# Epoch 10/10
# ----------
#   0%|          | 0/77 [00:00<?, ?it/s]
# train Loss: 0.0426 Acc: 0.9939
#   0%|          | 0/10 [00:00<?, ?it/s]
# val Loss: 0.3515 Acc: 0.8911
#
# Training complete in 0m 28s
# Best val Acc: 0.927393

# %% [markdown]
# Finally, plot the confusion matrix for the three models by running the cell below.

# %%
y_label_reweighted, y_pred_reweighted, _, _ =  get_eval_results(model, dataloaders)
plot_confusion_matrix(y_label_reweighted, y_pred_reweighted, title='CM original')

y_label_reweighted, y_pred_reweighted, _, _ =  get_eval_results(model_reweighted, dataloaders)
plot_confusion_matrix(y_label_reweighted, y_pred_reweighted, title='CM reweighted')

y_label_rebalanced, y_pred_rebalanced, _, _ =  get_eval_results(model_rebalanced, dataloaders)
plot_confusion_matrix(y_label_rebalanced, y_pred_rebalanced, title='CM rebalanced')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
